# %% [markdown]
# ![Yellow%20Illustrated%20Deer%20Twitter%20Header.png](attachment:Yellow%20Illustrated%20Deer%20Twitter%20Header.png)

# %% [markdown]
# # Pandas

# %% [markdown]
# what is pandas ?
#
#  Pandas is a Python library used for working with data sets it can use it for data analyzing, data cleaning, data exploring, and data manipulating The name "Pandas" has a reference to both "Panel Data", and "Python Data Analysis" and was created by Wes McKinney in 2008

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#                                                          Wes McKinney

# %% [markdown]
# why we use pandas why not Excel ?
#
#  after the in formation era the company started expanding in online the data they gather where big Excel could't note able handel so this libray allow you to analyze hugh amount of data (Big Data) to get statistical conclusions

# %% [markdown]
# Offical Pandas Github - https://github.com/pandas-dev/pandas

# %% [markdown]
# Offical  Pandas wibsite - https://pandas.pydata.org/

# %% [markdown]
# # how to install  install pandas  and numpy

# %% [markdown]
# cmd>pip install pandas or python -m pip install pandas

# %% [markdown]
# 1)Install pyhon
# 2)install anaconda or anaconda min

# %% [raw]
# conda env > conda install pandas

# %% [raw]
# # or PyPI
# pip install pandas

# %%
anconda promt > conda install numpy
cmd > pip install numpy

# %% [markdown]
# numpy
# conda install numpy
# pip install numpy

# %%
print('hello','good')
# Out:
# hello good

# %%
print('hi')
# Out:
# hi

# %% [markdown]
# #  Pandas Data Structure

# %%
# importing the pandas library  and numpy
import numpy as np
import pandas as pd

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -illow (c:\users\bhagat surya\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\bhagat surya\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\bhagat surya\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\bhagat surya\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\bhagat surya\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\bhagat surya\anaconda3\lib\site-packages)

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -illow (c:\users\bhagat surya\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\bhagat surya\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\bhagat surya\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\bhagat surya\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\bhagat surya\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\bhagat surya\anaconda3\lib\site-packages)

# %% [markdown]
# # Series

# %% [markdown]
# #creating a series using pandas and numpy

# %% [markdown]
#  A Pandas Series is like a column in a table. It is a one-dimensional array holding data of any type.

# %%
a = np.array([1,2,3,4,5])
series= pd.Series(a)

# %%
type(a)
type(series)

# %%
print(series)

# %%
g= np.array(['a','b','c'])
series = pd.Series(g)
print(series)

# %% [raw]
# #crating index

# %%
b= np.array([1,2,3,4,5])
series1= pd.Series(a,index=['a','b','c','e','f'])

# %%
print(series1)

# %%
g= np.array(['a','b','c'])
series = pd.Series(g,index=['arrow','bag','cat'])
print(series)

# %%
roll_number = {'a':1,'b':2,'c':3,'e':4,'f':5}
series2= pd.Series(roll_number)

# %%
series2

# %% [markdown]
# #Pandas Series.map()

# %% [markdown]
# # Data Frame

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Pandas DataFrame is a widely used data structure which works with a two-dimensional array with labeled axes (rows and columns). DataFrame is defined as a standard way to store data that has two different indexes, i.e., row index and column index

# %%
df = pd.DataFrame()  
print (df)

# %%
df= pd.Series()
print(df)

# %%
#We can easily create a DataFrame in Pandas using list.
o =['pandas','numpy']
df=pd.DataFrame(o)#converting to Dataframe

# %%
df

# %%
#Create a DataFrame from Dict of Lists

# %%
import pandas as pd  
info = {'ID' :[101, 102, 103],'Department' :['B.Sc','B.Tech','M.Tech',]}  
df = pd.DataFrame(info)  
print (df)

# %%
#Create a DataFrame from Dict of Series

# %%
df.shape

# %%
df.size

# %%
info = {'one' : pd.Series([1, 2, 3, 4, 5, 6], index=['a', 'b', 'c', 'd', 'e', 'f']),  
   'two' : pd.Series([1, 2, 3, 4, 5, 6, 7, 8], index=['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h'])}  
  
d1 = pd.DataFrame(info)  
print (d1)

# %%
#Column Selection

# %%
info = {'one' : pd.Series([1, 2, 3, 4, 5, 6], index=['a', 'b', 'c', 'd', 'e', 'f']),  
   'two' : pd.Series([1, 2, 3, 4, 5, 6, 7, 8], index=['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h'])}  
  
d1 = pd.DataFrame(info)

# %%
d1

# %%
d1.one

# %%
d1.two

# %%
d1['one']

# %%
data = {
  "run": range(1,10,1),
  "duration":range(31,40,1)
}

df = pd.DataFrame(data)

print(df)

# %%
df

# %%
#value count
df.value_counts()

# %%
data = {
  "stock": [420, 380, 390],
  "per_day_Sales": [50, 40, 45]
}

df = pd.DataFrame(data, index = ["day1", "day2", "day3"])

print(df)
